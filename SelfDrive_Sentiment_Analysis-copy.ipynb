# %% [markdown]
# <a href="https://colab.research.google.com/github/fatimasadiq/My_first_project/blob/master/SelfDrive_Sentiment_Analysis-copy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Self Driving Car Sentiment Analysis
# Steps are given below :
# 1. Data Extraction (but self Driving car data is taken from kaggle)
# 2.Preprocessing of data is done
# 3.Frequecy of words is generated.
# 4.Word Cloud is generated
# 5.Sentiment Aalysis is done
# 6.Heatmap is still progress

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
#import pandas as pd
import time
import csv

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import pandas as pd
import numpy as np
import keras
from keras.preprocessing.text import Tokenizer
tk = Tokenizer()
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
stop_words = set(stopwords.words('english'))
import string
import inflect
import seaborn as sn
p = inflect.engine()
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# !pip install twitter-text-python
# Out:
# Collecting twitter-text-python
#   Downloading https://files.pythonhosted.org/packages/29/a9/3d9cc947dea07e42f55a3c9de741ceeea766f841bc08297605a6370dfca0/twitter-text-python-1.1.1.tar.gz
# Building wheels for collected packages: twitter-text-python
#   Building wheel for twitter-text-python (setup.py) ... done
#   Created wheel for twitter-text-python: filename=twitter_text_python-1.1.1-cp36-none-any.whl size=10043 sha256=39fccc0fb65aeeadf5f7fa6f97587da7eb1f08fc2c869c94640ab69f38000eb6
#   Stored in directory: /root/.cache/pip/wheels/08/a4/8b/fc095442f760d0103f128b052ca90c46485077541c5a6a86bc
# Successfully built twitter-text-python
# Installing collected packages: twitter-text-python
# Successfully installed twitter-text-python-1.1.1

# %%
#Tweet Preprocessing

# emojis , special Character, URLS, tags
from ttp import ttp
import re
def cleanUrls(tweet):
    p = ttp.Parser()
    cleaned = tweet
    urls = p.parse(tweet).urls
    tags = p.parse(tweet).tags
    #schar = p.parse(tweet).schar
    # replies = p.parse(tweet).reply
    # print('replies', replies)
    for url in urls:
        cleaned = cleaned.replace(url, '')
    for tag in tags:
        cleaned = cleaned.replace('#'+tag, '')
    #for spchr in schar:
       #cleaned = cleaned.replace('ÃŒÂ¢â€°Ã¢Ã‚â€°Ã£Â¢s' ,'')

    print('.')
    return cleaned

# %%
import pandas as pd
#from tweetProcess import cleanUrls

tweets = pd.read_csv('data/Twitter-sentiment-self-drive-DFE-textonly.csv',encoding="ISO-8859-1", usecols=['tweets'])
for index, tweet in tweets.iterrows():
    c = cleanUrls(tweet[0])
    if len(c) > 40:
        df = pd.DataFrame([c])
        df.to_csv('cleaned.csv', mode='a', header=False, index=None)
print('finished')
# Out:
# Streaming output truncated to the last 5000 lines.
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# finished

# %%
df = pd.read_csv('data/Twitter-sentiment-self-drive-DFE-textonly.csv',encoding="ISO-8859-1", usecols=['tweets'])
df.head()
# Out:
#                                               tweets
# 0  Two places I'd invest all my money if I could:...
# 1  Awesome! Google driverless cars will help the ...
# 2  If Google maps can't keep up with road constru...
# 3  Autonomous cars seem way overhyped given the t...
# 4  Just saw Google self-driving car on I-34. It w...

# %%
from string import punctuation
def strip_punctuation(df):
    return ''.join(c for c in df if c not in punctuation)

# %%
print (strip_punctuation(df))
# Out:
# tweets

# %%
cleaned = []
for index, tweet in df.iterrows():
  words = tweet[0].split()
  # print(len(words))
  tweet = ''
  for word in words:
    word = word.lower().strip()
    
print (strip_punctuation(" " + tweet + word + " "))
# Out:
#  hat

# %%
def is_Mention(word):
      if word[0] == '@' or word[0] == '#':
            return True
      return False

def is_Number(word):
      try:
        int(word)
        return True
      except:
        return False

def is_RT(word):
  return word == 'rt'

def is_link(word):
  urls = re.findall('https?://(?:[-\w.]|(?:%[\da-fA-F]{2}))+', word)
  return len(urls) > 0

def is_stop_word(word):
  return word in stop_words

def has_sc(word):
  pat ='[|\^&+()\%*/=!>.,:?"\'\!ì¡‰ûó0123456789`@Ã$ŒÂ¢â€°Ã¢Ã‚Ã¥]'
  sc = re.findall(pat, word)
  return len(sc) > 0

# %%
cleaned = []
for index, tweet in df.iterrows():
  words = tweet[0].split()
  # print(len(words))
  tweet = ''
  for word in words:
    word = word.lower().strip()
    # print(word)    
    if is_Mention(word) or is_Number(word) or is_RT(word) or is_link(word) or is_stop_word(word) or has_sc(word):
      pass
      # tweet = tweet.replace(word, " ")             
    else:
      tweet = " " + tweet + word + " "

  cleaned.append(tweet.strip())

# %%
cleaned_tweets = np.array(cleaned)
pd.DataFrame(cleaned_tweets, columns=None).to_csv('cleaned_tweets.csv', index=None)

# %%
#Frequency Generation for the Word Cloud
#  lets make a histogram first and store it in csv
import pandas as pd
import pprint
stopWords = {'ourselves', 'hers', 'between', "let's", '&amp;', 'yourself', 'but', 'again', 'there', 'about', 'once', 'during', 'out', 'very', 'having', 'with', 'they', 'own', 'an', 'be', 'some', 'for', 'do', 'its', 'yours', 'such', 'into', 'of', 'most', 'itself', 'other', 'off', 'is', 's', 'am', 'or', 'who', 'as', 'from', 'him', 'each', 'the', 'themselves', 'until', 'below', 'are', 'we', 'these', 'your', 'his', 'through', 'don', 'nor', 'me', 'were', 'her', 'more', 'himself', 'this', 'down', 'should', 'our', 'their', 'while', 'above', 'both', 'up', 'to', 'ours', 'had', 'she', 'all', 'no', 'when', 'at', 'any', 'before', 'them', 'same', 'and', 'been', 'have', 'in', 'will', 'on', 'does', 'yourselves', 'then', 'that', 'because', 'what', 'over', 'why', 'so', 'can', 'did', 'not', 'now', 'under', 'he', 'you', 'herself', 'has', 'just', 'where', 'too', 'only', 'myself', 'which', 'those', 'i', 'after', 'few', 'whom', 't', 'being', 'if', 'theirs', 'my', 'against', 'a', 'by', 'doing', 'it', 'how', 'further', 'was', 'here', 'than'}
tweets = pd.read_csv('data/cleaned_tweets.csv',encoding="ISO-8859-1", header=None)
text = ''
freq = {}
for index, tweet in tweets.iterrows():
    words = tweet[0].split()
    for word in words:
        word = word.lower()
        if len(word) > 3 and word[0] != '@' and word not in stopWords:
            if word not in freq.keys():
                freq[word] = 1
            else:
                freq[word] += 1

# print(freq)
df = pd.Series(freq).to_frame()
df.to_csv('frequency.csv', mode='w')

# pp = pprint.PrettyPrinter(indent=4)
# pp.pprint(freq)

# %%
# now you have to do some manual changes in frequency file, by adding a row  and give i name words and frequency and sort it from largest to smallest

# %%
#Word Cloud Generation , The result  is taking on top 90 words

# Python program to generate WordCloud
# importing all necessery modules
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# Reads 'Youtube04-Eminem.csv' file
# df = pd.read_csv(r"Youtube04-Eminem.csv", encoding="latin-1")
df = pd.read_csv('data/cleaned_tweets.csv', header=None)
comment_words = ' '
stopwords = set(STOPWORDS)
stopWords2 = {'ourselves', 'first','still','could','says','hers', 'between', "let's", 'amp', '&amp;', 'yourself', 'but', 'again', 'there', 'about', 'once', 'during', 'out', 'very', 'having', 'with', 'they', 'own', 'an', 'be', 'some', 'for', 'do', 'its', 'yours', 'such', 'into', 'of', 'most', 'itself', 'other', 'off', 'is', 's', 'am', 'or', 'who', 'as', 'from', 'him', 'each', 'the', 'themselves', 'until', 'below', 'are', 'we', 'these', 'your', 'his', 'through', 'don', 'nor', 'me', 'were', 'her', 'more', 'himself', 'this', 'down', 'should', 'our', 'their', 'while', 'above', 'both', 'up', 'to', 'ours', 'had', 'she', 'all', 'no', 'when', 'at', 'any', 'before', 'them', 'same', 'and', 'been', 'have', 'in', 'will', 'on', 'does', 'yourselves', 'then', 'that', 'because', 'what', 'over', 'why', 'so', 'can', 'did', 'not', 'now', 'under', 'he', 'you', 'herself', 'has', 'just', 'where', 'too', 'only', 'myself', 'which', 'those', 'i', 'after', 'few', 'whom', 't', 'being', 'if', 'theirs', 'my', 'against', 'a', 'by', 'doing', 'it', 'how', 'further', 'was', 'here', 'than'}
tweets = pd.read_csv('data/frequency.csv', usecols=['words'], nrows=120)
hfwords = set()
for index, tweet in tweets.iterrows():
    hfwords.add(tweet[0])


# iterate through the csv file
for index, val in df.iterrows():
    # typecaste each val to string
    val = str(val[0])
    # split the value
    tokens = val.split()
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
    for word in tokens:
        if len(word) > 3 and word[0] != '@' and word not in stopWords2 and word in hfwords:
            comment_words = comment_words + word + ' '
wordcloud = WordCloud(width=800, height=800,
                      background_color='black',
                      stopwords=stopwords,
                      collocations=False,
                      min_font_size=5).generate(comment_words)
# plot the WordCloud image
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
 # Sentiment Analysis of tweets
 import pandas as pd
# from tweetProcess import cleanUrls
# import numpy as np
def sentimentAnalysis(points):
    if points > 0:
        return 'Positive'
    if points < 0:
        return 'Negative'
    return 'Neutral'


pWords = pd.read_csv('data/positiveWords.csv', encoding="ISO-8859-1", usecols=['positive'])
nWords = pd.read_csv('data/positiveWords.csv', encoding="ISO-8859-1", usecols=['negative'])
tweets = pd.read_csv('data/cleaned_tweets.csv', encoding="ISO-8859-1")

sent = []
p = []
text = []
pos =[]
neg = []

for index, tweet in tweets.iterrows():
    points = 0
    noofpositivewords=0
    noofnegativewords=0
    tweetArr = tweet[0].split()
    for index, word in pWords.iterrows():
# 7139
# 7140
# 7141
# 7142
# 7143
# 7144
# 7145
# 7146
# 7147
# 7148
# finished

# %%
senti = pd.read_csv('data/sentiments.csv',encoding="ISO-8859-1")

# %%
sn.axes_style('whitegrid')
sn.catplot('points', data=senti, aspect=3, kind='count', hue='sentiment', palette=['C1','C2', 'C0']).set_ylabels('count')

# %%
# Heatmap

# %%
freq = {}
for tweet in cleaned_tweets:
  for word in tweet.split():
    if word in freq:
      freq[word] +=1
    else:
      freq[word] = 0

# %%
word_frequency = np.array(list(freq.items()))

# %%
nouns = ['cars','vehicle','google','wheel',]
verbs = ['driverless',	'self-driving',	'autonomous',	'love',	'driving','cool','technology']

# %%
cleaned_tweets[0]
# Out:
# 'two places invest money printing self-driving'

# %%
# dict = [noun-verb-count]
dic = []
for noun in nouns:
  for verb in verbs:
    count = 0
    for tweet in cleaned_tweets:
      for word in tweet.split():
        word = word.lower()
        if word.lower() == verb:
          if noun in tweet.split() or p.plural(noun) in tweet.split():
            count += 1
    dic.append([noun, verb, count])

# %%
nouns_verbs_freq = np.array(dic)

# %%
df3 = pd.DataFrame(nouns_verbs_freq, columns=['noun', 'verb', 'frequency']).to_csv('nouns-verbs-frequency.csv', index=None)

# %%
flights_long = pd.read_csv('nouns-verbs-frequency.csv')

# %%
flights = flights_long.pivot("noun", "verb", "frequency")

# %%
ax = sn.heatmap(flights , vmin=0, vmax=90)

# %% [markdown]
# Tasks for this week
# 1. increase the count of noun and verbs in heat map
# 2.replace group of similar meaning words with one word and then create a heatmap

# %%
#Task1

# %%
freq = {}
for tweet in cleaned_tweets:
  for word in tweet.split():
    if word in freq:
      freq[word] +=1
    else:
      freq[word] = 0

# %%
word_frequency = np.array(list(freq.items()))

# %%
nouns = ['cars','vehicle','google','wheel','traffic','accidents','parking','maps','internet','fuel','city','street','insurance','future','safety','electric','human']
verbs = ['driverless',	'self-driving',	'autonomous',	'love',	'driving','cool','technology','drive','steering','mastering','testing','invented','automated','need','reshape','rides','taxis','design','excited',]

# %%
# dict = [noun-verb-count]
dic = []
for noun in nouns:
  for verb in verbs:
    count = 0
    for tweet in cleaned_tweets:
      for word in tweet.split():
        word = word.lower()
        if word.lower() == verb:
          if noun in tweet.split() or p.plural(noun) in tweet.split():
            count += 1
    dic.append([noun, verb, count])

# %%
nouns_verbs_freq = np.array(dic)

# %%
df3 = pd.DataFrame(nouns_verbs_freq, columns=['noun', 'verb', 'frequency']).to_csv('nouns-verbs-frequency.csv', index=None)

# %%
flights_long = pd.read_csv('nouns-verbs-frequency.csv')

# %%
flights = flights_long.pivot("noun", "verb", "frequency")

# %%
ax = sn.heatmap(flights , vmin=0, vmax=70)

# %%
#Task2

# %%
#dictionary
group={}
group['selfdriving'] =['self-driving' ,'self' ,'driving','driver-less']
group['car'] =['cars' ,'car','vehicle','vehicles','uber','wheel','tesla','toyota','taxi','mercedes-benz','mercedes-','cars;','nissan','wheels']
group['google'] = ['gooleplex','googles','google[x]','googlex','google-controlled', 'googler' , 'google-y','gestures#google','googlers','googlebots','[google]','futuregoogle']
group['city'] = ['francisco','standford','california','michigan','florida']
group['autonomous'] = ['automotive','semi-autonomous','fully-autonomous','non-autonomous','autonomously','autonomous-','automated','fully-automated']
group['love'] =['like','great','cool','awesome','smart','amazing','coolest']
group['technology']=['tech']
group['accident']=['accidents','crashes','issues','disrupt','terrible','incident','incidents']
group['dislike']=['lazy','drunk','shit','fuck','blind','crazy','stupid','fear']

# %%
grouped_tweets = []
# for tweet in cleaned_tweets[0:5]: for checking first 5 tweets only
for tweet in cleaned_tweets:
  for word in tweet.split():
    for sub_group in group:
      if word in group[sub_group]:
        tweet = tweet.replace(word, sub_group)
  grouped_tweets.append(tweet)

# %%
grouped_tweets
# Out:
# ['two places invest money printing selfdriving',
#  'google driverless car help dislike travel often;',
#  'google maps keep road supposed trust driverless car get around',
#  'autonomous car seem way overhyped given technology challenges; pilotless planes seem much doable',
#  'saw google selfdriving car painted green',
#  'driverless car eventually replace car drivers',
#  'chicago metro expected fully autonomous',
#  'love infotainment system new thing almost drive',
#  'autonomous car could reduce traffic fatalities',
#  'driverless car worth want highway server accident',
#  'driverless car legal city',
#  'audi first carmaker get license nevada dmv test autonomous',
#  'audi says first car manufacturer world get license nevada dmv test autonomous car make',
#  'buying one audi ready test autonomous car public roads',
#  'audi test selfdriving driverless car tampa pretty',
#  'audi first automaker city test selfdriving',
#  'audi gets first permit test selfdriving car city',
#  'audi gets permit test selfdriving car city',
#  'mercedes get first selfdriving car test car without drivers may soon',
#  'audi gets first permit test driverless car bay area drag queens say',
#  'today state regs autonomous car go audi america gets permit test driverless car public per',
#  'audi gets first permit test selfdriving car think twice next time tailgate new',
#  'audi gets first permit test driverless car bay area drag queens say',
#  'audi gets permit test selfdriving car city',
#  'becomes first automaker given permit test selfdriving',
#  'audi snags first permit test selfdriving car los angeles audi',
#  'gets first permit test selfdriving car city roads',
#  'agv guided trapac dock',
#  'agv guided trapac dock',
#  'agv guided trapac dock',
#  'come join us sae on-road autonomous car standards committee open meeting',
#  'sae on-road autonomous car standards committee open meeting',
#  'possible dislike people drive autonomous car requires intervention need automation that#autoauto',
#  'transportation becoming service oems responsible autonomous car might well',
#  'really good presentation jan becker autonomous car check',
#  'autonomous car vs connected car',
#  'autonomous car conveyance apparatus transportation system',
#  'autonomous car supposed behave',
#  'first ride autonomous car staring',
#  'chris director selfdriving car speaking autonomous car symposium',
#  'autonomous car supposed behave',
#  'home ongoing experiment talking autonomous car test site groundbreaking today',
#  'thank gods autonomous car condition evaluation',
#  'collaborative car control using human operator autonomous controller',
#  'wow - google goes company teams continental autonomous car',
#  'autonomous car motor car',
#  'new autonomous car regulations define autonomous new term',
#  'last google warned would autonomous car product not-too-distant',
#  'sensors fusion hybrid autonomous research car',
#  'ford revealed autonomous ford fusion hybrid pretty ford',
#  'fusion autonomous hybrid research light sensors',
#  'gm announces new autonomous connected car technologies cadillac',
#  'gm announces new autonomous connected car technologies cadillac model',
#  'dematic introduces pallet delivery autonomous guided car system grand rapids supplier',
#  'gm announces new autonomous connected car technologies cadillac model',
#  'fully autonomous car enabled',
#  'lexus autonomous research car',
#  'reason autonomous car drink',
#  'car fully autonomous electric car',
#  'boarded autonomous car symposium use conference related tweets',
#  'gearing autonomous car symposium use conference related tweets',
#  'insurance markets ready shift product vs personal mt car autonomous car',
#  'autonomous car quite potential business case markets love north america speeds every single road even',
#  'car autonomous car year sign',
#  'ripple effects autonomous car far yet see possibilities major strategic',
#  'google reportedly working considering autonomous car service -',
#  'throwing would totally beta test autonomous',
#  'good job implying sentient car involved accident',
#  'musk reluctant partner android autonomous smart-car would',
#  'autonomous car concept brings business class road',
#  'autonomous car fl among first embrace technology real business opportunities state thanks law',
#  'mark building testing autonomous car google - years results current car',
#  'morgan stanley finally put precise date autonomous car',
#  'gonna take autonomous car could drive tell puc clarify',
#  'love update good description existing car functions',
#  'stanford autonomous car la',
#  'forget autonomous car give people technology open car door without singing car next',
#  'autonomous',
#  'waiting lexus presser autonomous car technology hoping make mandalay bay convention center',
#  'closer previously autonomous drivers hands full get car',
#  'car executive new autonomous lexus call robot car',
#  'huge advances autonomous hate audi unveiled selfdriving car park',
#  'car showcased autonomous car technology ces -',
#  'autonomous big car makers letting take lead selfdriving',
#  'mercedes autonomous long-distance give car run',
#  'powered autonomous',
#  'car unique perspectives connected autonomous car sxsw',
#  'saw autonomous car lake anyone know company might',
#  'one autonomous test car generates camera data per hour vw car must become data',
#  'selfselfdriving selfdriving autonomous car',
#  'finished rush hour wait autonomous google',
#  'unique concept; sure autonomous car doubles room',
#  'love article transportation opt deliver car',
#  '-',
#  'acceptable level risk new reality people die autonomous car hard accept',
#  'itu gsma need accelerate kids hit road itu given keys autonomous car standards',
#  'autonomous car model letting car make money using even car',
#  'autonomous car paid visit nvidia pretty love person',
#  'love new autonomous self-parking car valet',
#  'meeting gm offices palo segway autonomous car',
#  'slowly steadily autonomous car help selfdriving',
#  'less five years use google autonomous get list',
#  'slowly steadily autonomous car help selfdriving aids',
#  'autonomous car easiest problem solve thanks cameras fault states via',
#  'safety mandates forecast drive autonomous car',
#  'hypermorgen icons near printable meat autonomous car warnings',
#  'family broke building stanford builds autonomous biker ran car full',
#  'realistic timeline full autonomous car hats',
#  'new murano offers advances technology getting closer goal autonomous car',
#  'selfdriving car autonomous car exhibit opening drive',
#  'come think looks love first selfdriving car',
#  'love car fully cause totally gonna sleep car',
#  'look forward seeing selfselfdriving car autonomous car selfdriving around district',
#  'ride google selfdriving lived tell',
#  'car debuts first-ever fly-by-wire automobile steering autonomous car gonna love',
#  'huge news week auto industry autonomous',
#  'autonomous car majority love learn car power',
#  'google unveils fully hands-free car prototype',
#  'human factor autonomous car take route',
#  'human factor autonomous car show summoned',
#  'human factor autonomous car flat',
#  'human factor autonomous car needs merge friends autonomous',
#  'car-phone evolved phone-car',
#  'could really use one phone activated autonomous drone car wash services right app called',
#  'happens car hits almost happen autonomous car hits bet lot',
#  'mapping car - autonomous slac national accelerator laboratory',
#  'whoa peeped autonomous google car',
#  'huge news week auto industry autonomous',
#  'google unveils selfdriving see buying autonomous',
#  'freescale autonomous car pretty love stuff ai [pic]',
#  'love video autonomous car opening tomorrow',
#  'john mit autonomous car combine sensors car knowledge detailed knowledge',
#  'reuss says google autonomous car looks kind love vw',
#  'announcement new selfselfdriving selfdriving car arrived time debate autonomous car',
#  'google unveils selfdriving see buying autonomous',
#  'imagine world dislike selfdriving dislike riding autonomous car safer sober',
#  'whilst may think autonomous car may solve accident naps risen',
#  'way way fun drive google bubble',
#  'driver autonomous',
#  'enthusiasts learn google car autonomous drive closer',
#  'dan connected goes connected car autonomous',
#  'autonomous drive leaf first selfdriving car plated japan; even demoed prime',
#  'wonder autonomous car include feeling',
#  'take quad copter make bigger carry people make would easier selfselfdriving selfdriving',
#  'thx bringing car technology literally drive',
#  'would buy autonomous selfdriving dubious downright',
#  'autonomous around could revolutionize entire design',
#  'autonomous car startup claims make car autonomous',
#  'sitting room full phds discussing future connected autonomous technology changes',
#  'autonomous selfdriving advantage - car drive shop wait around smelly waiting room',
#  'car fully autonomous car re-creates first long-distance drive',
#  'get autonomous car bring home',
#  'hackable car',
#  'see autonomous parking car action',
#  'showing video google autonomous car -- miles driven driver interaction across',
#  'see autonomous parking car action',
#  'google buy car mix little autonomous car mix solve transportation',
#  'dream mastered got run autonomous car named going circus school',
#  'car',
#  'hackable car',
#  'onboard autonomous car parked',
#  'fascinating presentation chris urmson head hill rayburn',
#  'next autonomous car',
#  'autonomous wwj business june continentalbreakfast',
#  'passed autonomous car',
#  'concept car key autonomous car',
#  'kit makes car autonomous',
#  'autonomous car hack',
#  'autonomous car volkswagen autonomous innovation laboratory',
#  'autonomous car selfdriving could free billion wasted car',
#  'car leaf prototype becomes first autonomous car hit japanese highways',
#  'need constantly supervise car autonomous',
#  'differentiating car experience huge autonomous car - mercedes benz',
#  'turn semi autonomous',
#  'oil thought camry autonomous car give damn time',
#  'educated new car years autonomous selfdriving',
#  'making autonomous make',
#  'ride autonomous car much latest fine fall put',
#  'driverless car make people see car without person autonomous shortened auto auto',
#  'drivers would opt autonomous selfdriving cheaper car insurance well',
#  'autonomous car panel',
#  'dislike autonomous car drive able write damn research paper',
#  'autonomous car support subject political attack ad',
#  'car following rear end new car require autonomous braking new car',
#  'car sized autonomous rover lands mars sunday go',
#  'put lay autonomous nuclear powered car landed mars using rocket',
#  'love projects worked robotics lab love autonomous car lego wccc love hands-on approach',
#  'truly basically car maybe reach',
#  'last night saw horse makes hope car silly autonomous car take market',
#  'love evaluation moral consequences autonomous car child road',
#  'love summer shelley autonomous race upgraded e-stop gps safety new java telemetry app map',
#  'google autonomous google',
#  'autonomous car likely nicknamed',
#  'flying car autonomous robot death car',
#  'raspberry pi work autonomous car telemetry data christmas holidays',
#  'watching video autonomous car sent',
#  'drive thyself race toward autonomous car design good stuff ahead',
#  'selectable ethics autonomous car could bad hate',
#  'driverless even autonomous car takes capital test',
#  'really dumb thing call car completely dependent monitored ford',
#  'looking forward day google amazon drones fight deliver autonomous car',
#  'illegal drive wearing google selfdriving autonomous car',
#  'unless car autonomous selfdriving enjoy vids',
#  'autonomus car drive miss hope ~ autonomous car legal city autopia wired',
#  'close selfdriving reality via',
#  'close selfdriving reality via',
#  'build autonomous car real fast make drive',
#  'autonomous car technology blurb npr',
#  'car technology clout helps win legislative support selfdriving',
#  'hints next gen shown also says make full autonomous car production news',
#  'connected autonomous car technology selfdriving real deal',
#  'going miss selfdriving',
#  'aspiring car designers challenge design ideas support autonomous future mobility',
#  'pledges mass produce fully autonomous car',
#  'side autonomous google car rolled beside said would',
#  'autonomous',
#  'rr first autonomous car car',
#  'sucks luddites appreciation fine autonomous car technology love always',
#  'selfdriving car still many flaws via',
#  'car ceo musk sees fully autonomous car ready five six years via',
#  'ceo talking right autonomous car concept uses less weight',
#  'became first car company receive autonomous car permit city future',
#  'car ceo musk sees fully autonomous car ready five six',
#  'trying contact autonomous hard talk',
#  'autonomous car ready car ceo',
#  'autonomous car change urban - convinced want learn',
#  'audi gets second autonomous car license via',
#  'audi car park themselves-first automaker car license',
#  'autonomous car legislation manufacturer plates already exist dumb marketing',
#  'ces image autonomous car something may see las vegas valley',
#  'car lexus showcase autonomous research car techhive via',
#  'car motor corp lexus reveal autonomous research car ces',
#  'already',
#  'actively modifying field view autonomous car view',
#  'autonomous car manufacturers assume risk catalyst adoption accident insurance',
#  'ford google looking commercial driver less',
#  'gotta look',
#  'modifying behavior autonomous car based predicted behavior',
#  'ite technical conference - love autonomous car presentation',
#  'completely agree bran quote next pantheon internet - autonomous',
#  'car pool continue -',
#  'getting vibe car conversation',
#  'minnesota autonomous car hack factory minnesota -',
#  'hope google overlords perfect autonomous car fast enough fb tweet without',
#  'autonomous car competition',
#  'qnx helps drive new autonomous car project',
#  'hey check powered autonomous car',
#  'proper procedure cop pull autonomous',
#  'good passenger proper procedure cop pull autonomous',
#  'true inspiration',
#  'may last autonomous car',
#  'winning robosub university autonomous underwater car',
#  'builds first purpose-built autonomous car',
#  'think going -- reuss autonomous car',
#  'autonomous car testing facility says david',
#  'design changes expectations; may choose wearable device experience driving- case autonomous car',
#  'autonomous car',
#  'transitioning mixed-mode car autonomous mode',
#  'dmv solicits public feedback autonomous car regulations',
#  'director autonomous car anthony levandowski',
#  'autonomous drive eventually preclude entire stages car shortening dynamics',
#  'first commercially avail autonomous car world made help unicor used',
#  'glad autonomous heavy rain worse selfdriving',
#  'first commercially avail autonomous car world made help used',
#  'ohio state launches million center study advance car funded',
#  'autonomous car system',
#  'one solution poor dc cab call autonomous',
#  'chris urmson really boosted hope autonomous car viability near future',
#  'heard thru apple started autonomous car effort compete already poaching engineers',
#  'cmu autonomous car',
#  'enters autonomous car series',
#  'cross fingers google autonomous car',
#  'petersen discussing autonomous car',
#  'behold autonomous back su',
#  'look forward speaking city autonomous car summit friday innovation transportation',
#  'would entice get behind car autonomous new study shows',
#  'meet expands facilities car research',
#  'senator showcases autonomous car technology',
#  'kinda tempted start playing reverse bumper tag google unpersoned autonomous car behind',
#  'foreseeable human must available drivers seat take control even car autonomous capable',
#  'ohio state autonomous car expert featured article computer next',
#  'need clean camera camera control car using autonomous rendezvous capture',
#  'autonomous car assurance internship via',
#  'radar cruise control basically autonomous braking acceleration maximum steer',
#  'drive partially autonomous car cruise technology life',
#  'jeff fully autonomous car moon shot',
#  'require extra autonomous car testing allowed city law',
#  'city governor approves autonomous car testing',
#  'city gives green light autonomous car testing despite concerns city soon',
#  'auto lidar heat map fusion hybrid autonomous research car',
#  'city latest state approve autonomous car',
#  'city gives green light autonomous car testing despite concerns city soon',
#  'ford shows new autonomous selfdriving research car got lasers',
#  'autonomous surface car automates dirtiest jobs',
#  'selfdriving traffic last night fought urge cut google autonomous help',
#  'tune ca brown signs autonomous car bill',
#  'years ago knight rider autonomous car future trans',
#  'autonomous car drivers license without states vote',
#  'governor snyder announced signing autonomous car bill denso',
#  'packed house thanks friends autonomous car enthusiasts coming',
#  'byd singapore institute collaborate autonomous electric car technology mass transportation -',
#  'description low-speed autonomous love see fw someday',
#  'licence plate number autonomous car took',
#  'date autonomous car challenge',
#  'autonomous road car',
#  'start building rc car brought monster truck rc let',
#  'given ornery rude driver looking forward gets replaced autonomous car',
#  'mt elon musk says autonomous electric car road years',
#  'autonomous car selfdriving permit looks',
#  'another exciting advance car safety emerg braking systems',
#  'given ornery rude driver looking forward gets replaced autonomous car',
#  'day national association motor car full forward hearing autonomous car',
#  'install cameras study city football mt mi install cameras freeways autonomous car study',
#  'ford u-m team promote autonomous car southeast city lead',
#  'verizon autonomous car could happen edward cardenasdetroit ceo',
#  'tomorrow bernard soriano stage ca leader autonomous car laws',
#  'hardware autonomous selfdriving car size ipad vs filling trunk --',
#  'going autonomous car want come google',
#  'someone drove darpa car',
#  'darpa sponsor selfdriving',
#  'selfselfdriving selfdriving car began darpa',
#  'soon sound ridiculous',
#  'carnegie mellon shows selfdriving',
#  'okay vision necessary via',
#  'driverless argh overwhelming google scary',
#  'gm says almost-driverless car coming milford - sometime end',
#  'plans offer driverless car',
#  'gm says almost-driverless car coming sometime end',
#  'general motors promises nearly driverless car end decade sometime',
#  'driverless car really around headlights ready pounce',
#  'car returns buys google driverless car - redorbit',
#  'driverless car could actually love',
#  'car plans offer driverless car',
#  'carmakers going really talk paper bag driverless message',
#  'need plan outlook cdl drivers good thanks driverless wonder handle fed',
#  'car purchase driverless car google techcrunch love',
#  'teacherless driverless car miley cyrus foam world coming',
#  'thought trying find car stick already driverless car bring new meaning auto vs',
#  'wait try car purchases driverless car',
#  'car purchase driverless car google love investment',
#  'assume driverless car able sense traffic adjust accordingly faster',
#  'students test driverless car',
#  'race b first state driverless car economic competitive edge',
#  'car purchase driverless car',
#  'dispatch car driverless car via',
#  'motorcyclist love volunteer services testing driverless car deal trolled motorcycles',
#  'wait try car purchase driverless car google',
#  'car purchase driverless car google getting',
#  'oh hai making driverless transportation come',
#  'oh hai making driverless transportation come',
#  'dispatch car purchase driverless car',
#  'google ventures invests million driverless car via',
#  'tv show plot big insurance exec tries kill driverless car industry destroying safety record using giant picture empty road',
#  'driverless google car car actually make want flying car',
#  'wants use driverless car still want able rate driver bad ones',
#  'driverless car stocked best sellers respond sales via twitter txt',
#  'first drive feels driverless',
#  'gm says almost-driverless car coming',
#  'faked guess geeking love driverless car would clouded bs',
#  'last time rode car cab door handles filled buy driverless car',
#  'proposed effects driverless car things policy-- one interesting discussions right',
#  'general motors promises nearly driverless car end decade system',
#  'gm says almost-driverless car coming general motors says end decade',
#  'car says release driverless car good humans accident selfdriving',
#  'driverless',
#  'brilliant sci fi piece tc - purchase driverless car google',
#  'thinking driverless technology wish could bear',
#  'perhaps future driverless google taxis order',
#  'google going build driverless car via',
#  'driverless car',
#  'wait day driverless car make parking tickets searching parking spots things',
#  'thought thing actually - must strategic motive well driverless car see',
#  'car purchase driverless car google goog cabbies',
#  'going buy driverless car proving everything car drivers saying disruptive app company',
#  'guess going around driverless car sf',
#  '[new blog] driverless car beginning -',
#  'want driverless states investing love transportation via',
#  'carry hit somehow doubt goes',
#  'tucson worst drivers need create students test driverless car',
#  'curious feel driverless car impact cities',
#  'also google driverless car accident rate date',
#  'driverless',
#  'wrestling terror driverless car vs dislike',
#  'yes driverless',
#  'google hurry dislike driverless',
#  'schmidt says gigabit internet kansas city important driverless',
#  'problem driverless car change took long enough teach women',
#  'forget driverless excited hear google working immortality',
#  'eric schmidt google mn human driverless car stop freaking',
#  'driverless chairs moved brain robots actively learn new turn channel',
#  'saw first google driverless car sure driver hands car though',
#  'day hail driverless name',
#  'got behind google driverless car going fast flashed lights move',
#  'chief legal officer david drummond far huge urban planning',
#  'law text drive driverless car',
#  'interesting exploration driverless car might make tough ethical decisions via',
#  'larry driverless connected car need fuel cells',
#  'dear please hurry driverless ones driven humans making',
#  'guys convinced government need driver every driverless automobiles long way',
#  'driverless car liberate humanity finally allowing shift sing occupancy car zero occupancy',
#  'type faster years driverless -- elon musk',
#  'tampa bay bottom line people buy',
#  'car exciting need system-wide reimagination',
#  'government wants car talk via',
#  'wish driverless car right',
#  'drive driverless car could game changer insurance costs',
#  'driverless car slams az home inches sleeping according police truck smashed',
#  'volvo also making prototype nhtsa level',
#  '- driverless car save time accident ask let humans launch',
#  'driverless car',
#  'technology driverless car make car better',
#  'driverless car',
#  'agree seems much work needs done infrastructure driverless car',
#  'could hub wireless driverless explores future car',
#  'predict google buy car create driverless transit little self-serve bars resurrect',
#  'rumor agreed car public demonstration projects several',
#  'check google driverless',
#  'chart driverless car',
#  'talking driverless car',
#  'half americans want live love city driverless car',
#  'driverless car better drivers',
#  'people first buy driverless',
#  'interesting discussion driverless car questions driverless car -',
#  'anyone think metaphor driverless',
#  'gets ticket crash one driverless oomph',
#  'hope study suggests nearly car expected driverless',
#  'car going make driverless',
#  'auburn hills driverless car set hit nevada continental auburn hills today became',
#  'get ready mother generation driverless car',
#  'driverless car removed winter selfdriving situational patience actual',
#  'feel free email thoughts driverless may followup email twitter',
#  'need driverless car asap - check',
#  'could cut accident paving way driverless car',
#  'computer drives robotic driverless',
#  'car car drivers facebooking bad enough drive without driverless car',
#  'selfdriving come',
#  'software updates connected car -- hackers -- driverless car send much potential',
#  'driverless car issue wants hear',
#  'broad driverless car saas ecommerce cold need see deck seed',
#  'larry burns replacing car driverless upshift vision',
#  'driverless car designed use mobile',
#  'born discussion driverless car dislike differential equations involved tracking road obviously',
#  'well long google selfdriving car',
#  'news wrote; technology advent driverless car amid',
#  'driverless get passenger seat drive',
#  'driverless standard car feature within',
#  'bad donut give ticket driverless',
#  'ca cancels driverless car state hwys car selfdriving tx tn search better',
#  'love overview bet autonomous driverless car technology easy',
#  'fasten driverless car worth trillions',
#  'driverless car worth want',
#  'around driverless',
#  'new positioning technology works think could robotics driverless car',
#  'analyst told us manufacturers think driverless car commercially viable eliza',
#  'find technical information google driverless',
#  'story headline today lexus previews driverless car see car time apparently without',
#  'driverless car',
#  'dad obsessed google driverless artificial gonna',
#  'audi shows driverless car also pick heard car drive',
#  'awesome-ubuntu phone coming saw lots innovation smaller driverless lexus',
#  'driverless',
#  'tells story cab drivers askd abt driverless',
#  'driverless-car single lane freeway could transport car today',
#  'want driverless car',
#  'gets blame driverless car gets',
#  'innovation finest trillion driverless car b commercialized sooner u think',
#  'blame driverless car gets legal implications selfdriving',
#  'simultaneously love new driverless parking system demonstrated [video]',
#  'simultaneously love new driverless parking system demonstrated [video]',
#  'blame driverless car liability concerns slowing legislative rare',
#  'driverless car going change',
#  'driverless dislike gets ticket running red',
#  'google already created driverless car legal cali think may junction car tho',
#  'driverless',
#  'ya stop future; selfdriving fatalities fell lowest since driverless car cheaper',
#  'driverless working',
#  'driverless car invented google completed miles two accident humans car hit',
#  'google streetview might one driver less',
#  'driverless car implications odd stares mt google driverless car worth trillions',
#  'fasten driverless car worth trillions',
#  'wait fasten driverless car worth trillions',
#  'honestly love thing fasten driverless car worth trillions',
#  'reading - driverless car change',
#  'love internet driverless car worth trillions san-less',
#  'prediction cities soon compete build driverless car',
#  'driverless car completed miles accident humans car hit love drunks',
#  'needed listening get driverless carssss',
#  'another article driverless car fails raise possible use bombings war',
#  'audi show driverless-car technology',
#  'driverless car libertarian answer solve use need',
#  'idiot owns driverless',
#  'going reaction driverless',
#  'watch employees freak car rolls quiet funny',
#  'watch mcdonalds employees freak car rolls gotta love',
#  'audi first automaker allowed put driverless car road',
#  'oh filing tomorrow morning floor driverless',
#  'ohio state researchers working car drive idea driverless car closer',
#  'long becomes prohibitively expensive insure non-driverless',
#  'guess selfdriving next driverless',
#  'bet cop one driverless',
#  'driverless car single lane freeway could transport car today',
#  'kramer enlists jackie sue google stealing idea driverless george impersonates jerry reddit',
#  'driverless dodging tires taking names',
#  'driverless car mass market-ready cea gartner says begin happening',
#  'dislike watching video driverless car going make better',
#  'yes driverless car accident everything driverless car worth trillions',
#  'u think think global love driverless might u design',
#  'driverless human',
#  'driverless car going change',
#  'beginning good series fasten driverless car worth trillions - forbes',
#  'nice see decades long ideas become',
#  'saw audi new driver less parking really love',
#  'driverless car ambulance chasing attorney google car must',
#  'trillion-dollar driverless car commercialized sooner think',
#  'trillion-dollar driverless car commercialized sooner think via',
#  'fasten driverless car worth trillions - forbes',
#  'driverless car worth',
#  'fasten driverless car worth',
#  'driverless car worth drive lot less',
#  'fasten driverless car worth',
#  'popular fasten driverless car worth trillions',
#  'sure glad road - land buses worry driverless mta',
#  'week artificial driverless car public arsenal flu cold',
#  'audi join google driverless looks love google competition driverless',
#  'google driverless car larry google ceo larry page wanted impress global',
#  'cnn said nv already legalized driverless car car us driverless',
#  'driverless already called texting selfdriving',
#  'audi unveils driverless car las vegas technology hot heels began testing',
#  'audi shows driverless car also pick heard car drive',
#  'excited music driverless going good',
#  'driverless car',
#  'blame driverless car gets legal implications selfdriving',
#  'idiot would ride driverless',
#  'dad lost car love literally lost car sitting',
#  'google google driverless car loon thru high alt',
#  'writing thesis paper driverless wondering know good resources cover',
#  'google invents driverless car invent carless',
#  'build emotion chip driverless car',
#  'google invents driverless car invent careless',
#  'intriguing article pointing could put cork',
#  'regional transportation council interesting testimony driverless fewer duis drivers licenses',
#  'want avoid living suburbs suckers ready driverless new leaf',
#  'driverless future transform economy',
#  'driverless future transform economy via',
#  'order car certain light indicator back front maybe',
#  'mt google considers buying driverless car buys car instead',
#  'suspect first driverless car built',
#  'google search turns gets google new quest cure death driverless',
#  'driverless car road ahead-how feel',
#  'good driverless car positive worry go wrong go terribly',
#  'google driverless cabs launch',
#  'google search turns gets google new quest cure death',
#  'google signs agreement nyc mayor replace nyc taxis driverless google cabs',
#  'google search turns gets google new quest cure death',
#  'future technology webinar brings good driverless car soon accident insurance',
#  'spot car plans offer driverless car',
#  'future thanks driverless revolution rolls -',
#  'driverless car coming get ask selfdriving',
#  'saw news coming driverless car b missing',
#  'odd people scared driverless car dislove drivers - people love killed robots',
#  'driverless car - foresight concept general motors- talk uc berkeley friend client rick holman',
#  'heard radio google might developing driverless',
#  'congressman test driverless cmu pittsburgh - pennsylvania congressman planning trip',
#  'car accident primary killer driverless car end get',
#  'canada ready selfdriving transportation advocate says driverless car could ready',
#  'canada ready selfdriving transportation advocate says driverless car could ready',
#  'selfdriving car could roads transportation advocate says driverless',
#  'love piece excellent trip driverless cadillac thru',
#  'driverless car toured campus legit',
#  'writing thesis paper driverless wondering know resources cover',
#  'writing thesis paper driverless wondering know quality resources cover',
#  'mt child hit driverless fewer children hit drivers',
#  'driverless car road ahead',
#  'driverless car road',
#  'thought nyc cabs going replaced google driverless',
#  'role program driverless type transparency citizens',
#  'autonomous love driverless need program variance',
#  'could program ethics driverless want program go little faster speed',
#  'infrastructure driverless car talk current trend',
#  'driverless car could shape get way design cities optimization programs changing day-to-day',
#  'driverless car alert motorists missing lane drivers must position',
#  'driverless car future insurance',
#  'dmv mulls regulate driverless los angeles sooner consumers able buy',
#  'city pushes finish driverless car rules',
#  'hoo city regulate driverless car end',
#  'ethical accident driverless repair shops losing',
#  'driverless car',
#  'projections show - gvt could mandate driverless car goodbye dislike backseat driver cherished leisure drive',
#  'city mulls regulate los angeles department motor car',
#  'city mulls regulate',
#  'big espresso machine - inside driverless car future',
#  'dope swivel big espresso machine - driverless car future',
#  'swivel big inside driverless car future',
#  'hivemind driverless car last step bring',
#  'crushing google driverless car',
#  'driverless roving car usually pull crosswalk making difficult car today driver',
#  'see driverless uavs us',
#  'wish would spend much developing jobs future spending replacing',
#  'pushes finish driverless car rules',
#  'says expert',
#  'city leads research connected driverless',
#  'would love driverless',
#  'interesting challenge driverless picking people airport busy arrivals use phone homing',
#  'time car goes know difference',
#  'one three states leading way -nancy sikes-kline',
#  'checking event future driverless car',
#  'facebook-oculus move recruiting keeping love engineers cares driverless got',
#  'driverless terminal felt love ampol car',
#  '-- driverless car',
#  'think long transit continues driverless solves',
#  'cannot wait tired people using car lethal weapons',
#  'automation flying driverless doctor learning;huge webinars quality',
#  'oh driverless',
#  'assume factor impact driverless undoubtedly ubiquitous',
#  'mention testing driverless',
#  'man dream driverless',
#  'driverless car future',
#  'want driverless someone invent one',
#  'sf construction technology driverless car coming need parking',
#  'predictions love economics driverless shall see indeed machines offset unemployment',
#  'make driverless make act selfdriving work',
#  'driverless car arrives geneva motor show via',
#  'heated debate regarding future driverless solution',
#  'driverless could fly',
#  'inside driverless car tweeted cuz',
#  'driverless car gets ticket one car ever really',
#  'swivel big espresso driverless car',
#  'idea challenge traditional autonomous geneva auto show sexy driverless car',
#  'journey inside driverless car',
#  'government still make money tickets car',
#  'regulatory environment driverless regulation hold us',
#  'love see rethink inside car much could change',
#  'otherwise driverless car challenge boon walkable',
#  'city mulls regulate department motor car wading',
#  'city mulls regulate city department motor car',
#  'enough bricks gas pedal car driverless car',
#  'man behind talks food including delivery groceries driverless car stay',
#  'retail buy store online; produce via delivered via drone driverless car',
#  'talking drones driverless car making home deliveries',
#  'driverless car ethical questions accompany lives dies car make',
#  'driverless interesting responsible algorithm decides lives dies split second',
#  'driverless car could free urban happen room right',
#  'city pushes finish driverless car rules',
#  'driverless car could shape ways design optimization programs change day-to-day',
#  'driverless car could become commercially available end decade',
#  'clear compelling efficiency improvement driverless relocating burning',
#  'seriously doubting agree car driverless',
#  'swiss canada ceo sharon ludlow considering future insuring drones driverless car annual outlook',
#  'driverless car future insurance business',
#  'driverless car wearable digital drives business',
#  'driverless car exist speeding tickets',
#  'driverless car glad come soon enough auto accident deaths',
#  'fully driverless car could reduce accident saving lives us',
#  'populist theorists driverless car reading metaphor',
#  'driverless manual gov corp go approved trips passenger compartment',
#  'saw enjoyable watching selfdriving car video almost',
#  'see google driverless car turning north college mind playing',
#  'government regulation crash driverless',
#  'google driverless car city sunshine googleplex',
#  'wait order groceries google glass riding driverless',
#  'happens driverless car',
#  'driverless car eyeglasses; internet wonderful wizards google targeting unwired people',
#  'get fast lane development',
#  'mph let driverless car via',
#  'driverless car combined would drastically improve asset reducing traffic',
#  'wondering selfdriving car may available interesting interview',
#  'driverless car invented google completed miles humans car hit',
#  'today impact driverless car roads much change',
#  'vision driverless car eliminates privately owned time come government turn car',
#  'strange pass google driverless car silicon valley interstate',
#  'pilotless planes jobs left human',
#  'driverless car full manual authorized destinations passenger',
#  'selfdriving love serious right',
#  'car without dmv hold june workshop driverless car regulations',
#  'anki drive - take google driverless',
#  'learned keynote morning driverless car quite',
#  'driverless car invented google completed miles two accident humans car hit',
#  'driverless car thought',
#  'driverless car invented google completed miles two accident humans car hit',
#  'google investing driverless car launching internet-enabled meanwhile fb engineers added another seconds mobile',
#  'guess one thing would make racing school founder want driverless driverless car sound love',
#  'dont trust selfdrivingdriving dont even trust damn selfdriving weak link',
#  'world driverless car heaven',
#  'world driverless car heaven',
#  'future ultimate driverless car report card',
#  'self-stopping car start next gen safety systems -gabe enough -',
#  'could driverless car call involved',
#  '- george jetson drove flying saucer - even conceived driverless',
#  'problem still want driverless humans waste transport',
#  'passive fishing pre-test selfdriving',
#  'driverless car horseless carriages',
#  'think much selfdriving infrastructure needed driverless stop example -- car adjust never',
#  'driverless promised hoverboards back',
#  'driverless car going obey traffic wait people get heads around',
#  'driverless car mastering city streets',
#  'drones driverless car raise questions future city services via',
#  'driverless car mastering city streets',
#  'driverless thousands miles airplanes auto',
#  'driverless thousands airplanes auto',
#  'drivers required cross state city nevada allow driverless car share border miles',
#  'driverless car master city los angeles - google says turned corner',
#  'driverless car mastering city google google says car programmed',
#  'google sends driverless car onto city works love type disney store takes princess themed strip',
#  'future practical driverless car might decided city test',
#  '',
#  'love would transparent car rather driverless',
#  'driverless car graphene flying car love blade runner',
#  'ask driverless car pay insurance response goes',
#  'audio apa member howard says driverless',
#  'close next giant leap driverless love homes private space cyborg cashless payments',
#  'driverless junk-punching anyone mass',
#  'interesting thoughts driverless car first never pondered possibilities',
#  'courier launch bound wait till hooks driverless car',
#  'first stage families downsize driverless car could sent family',
#  'driverless car mastering city streets future upon us',
#  'driverless car mastering city google says turned corner pursuit',
#  'driverless car mastering city streets',
#  'driverless car mastering city streets',
#  'google says driverless car mastering city google says turned corner pursuit',
#  'driverless car mastering city google says turned corner pursuit',
#  'car come soon enough - true',
#  'driverless car navigate road construction',
#  'driverless car navigate road construction',
#  'love overview',
#  'mastering city jaywalkers',
#  'wonder driverless car hindenburg moment - banned accept accident love planes driven car',
#  'driverless car mastering city streets',
#  'driverless car funded sterling jessica tandy need morgan freeman drive around anymore',
#  'love driverless car gets law handle',
#  'driverless roads dangerous enough actual people behind',
#  'driverless car mastering city google says car programmed drive',
#  'oh wait get rear ended one driverless',
#  'ok- dare tke spin driverless car',
#  'yes google says hope use driverless car shopping delivery',
#  'car never physics says via still much',
#  'car inch way closer reality coming',
#  'car industry survive driverless car - working minimize human fallout crucial',
#  'road redlight driverless car covered private flood insurance',
#  'driverless car',
#  'world driverless car far possible still engineers selfdriving',
#  'driverless car selfdriving hospital needed',
#  'hope driverless car get pretty eyesight getting pretty',
#  'aggressive drivers bully conservative ones coordinated driverless car could box offenders',
#  'driverless car navigate road construction',
#  'driverless car overcome dislike google says turned corner pursuit',
#  'driverless roads dangerous enough actual people behind',
#  'driverless car mastering city streets',
#  'love update performance driverless car - well worth watching minute video',
#  'happens driverless car runs road',
#  'driverless car master city upgrade morons hwy',
#  'google working driverless car niggas still trying figure get music video',
#  'stop gmos frogurt americans ready lab grown meat driverless',
#  'car change run business via let',
#  'driverless car equipped emergency first response',
#  'urban sprawl could decrease driverless given required reaction car',
#  'driverless car',
#  'time auto industry create new model yes model',
#  'chick trailer car race sunday antique selfdriving car',
#  'best thing would love flawlessly-dispatched driverless car',
#  'dislike google says driverless car mastering city google says',
#  'imagine selfdriving robot thats takes home fastest way',
#  'wrote report abt driverless car liability',
#  'driverless car reportedly mastering city los angeles google says car',
#  'driverless car',
#  'driverless car mastering city google says car programmed drive',
#  'says driverless car starting master city per wish hurry could drive',
#  'ensure politicians stand says driverless car ready city',
#  'google says driverless car mastering city google says turned corner pursuit',
#  'driverless done david hasselhoff',
#  'wrote friday overregulate driverless car today ap writes google',
#  'driverless car mastering city los angeles google says turned corner',
#  'google says driverless car mastering city google says turned corner pursuit',
#  'driverless car mastering city google says car programmed drive',
#  'fault driverless car report proposes legal need med',
#  'driverless car mastering city streets future',
#  'google says driverless car mastering city mountain view google says car',
#  'fewer injuries deaths occur driverless',
#  'cfrb talk driverless car',
#  'cant believe driverless scary time',
#  'concerned quickly driverless car technology legal game',
#  'apparently driver less car',
#  'good idea next ten years transition driverless',
#  'driverless',
#  'driverless taxis could',
#  'google driverless car know sucker always dd gets fun',
#  'oh car driverless yet',
#  'first driverless car think taking go',
#  'driverless car set hit road becoming law sounds dislike look',
#  'driverless car yrs see ag world ahead',
#  'driverless car computation oom complex predictive says',
#  'hey releasing tests test results software-controlled driverless car curious',
#  'wait driverless soooo',
#  'love presentation afternoon sebastian thrun driverless really fascinating',
#  'first driverless car think taking go',
#  'china test driverless car miles -',
#  'better tires driverless car would first thing tire',
#  'driverless',
#  'clearly never seen futuristic movie driverless recommend',
#  'driverless car change',
#  'driverless car street legal three computer accident car',
#  'changing tire says would happened driverless tire went',
#  'robot chauffeurs car future - sfgate car',
#  'obesity glass social interfacing driverless car',
#  'perfect driverless mobility actuated horrific dystopia portrayed pop scifi epic fault',
#  'google made driverless car ill longer mad find drive around block til',
#  'short-term driverless need roads',
#  'city nevada legalized driverless acceptance',
#  'think reinvention needed trucking taxis driverless car know way san jose',
#  'last week city legalized driverless -hersman',
#  'someone google announce driverless car programmed give cyclists feet',
#  'thank come fast economist driverless road ahead via',
#  'way ohare airport pass driverless car',
#  'see road dc looking legalizing selfdriving car though available',
#  'sebastian thrun google glass driverless car ccis',
#  'driverless road',
#  'included future',
#  'anyone else problem next phase driverless brakes steering car',
#  '-- google steers new course driverless car -',
#  'google determined build driverless car safe enough',
#  'invented selfdriving',
#  'big difference driverless car associated car',
#  'already driverless car called trains public also need infrastructure',
#  'new york times article selfdriving next phase driverless brakes steering car',
#  'google build mean',
#  'could interest driverless car spark resurgence',
#  'current cost car service nyc would per trip driverless fleet would',
#  'want sit day driverless car skype instant translator car',
#  'get driverless car drive telepresence-bot everyplace supposed could stay',
#  'google selfdriving car drops back',
#  'also banned segways way people ban driverless',
#  'driverless really',
#  'google plans driverless car road next love',
#  'co-hosting dig deep winners losers world google driverless',
#  'funny watching wouldnt get driverless car job',
#  'point selfdriving',
#  'new driverless think saw several road',
#  'google unveils driverless car complete steering car age laziness',
#  'late party realizing waze purchase quite intriguing consider driverless',
#  'google maps keep supposed trust driverless car get thru hwys around',
#  'get meet newest driverless car',
#  'google releasing driverless would solve problems save friends permanent chauffeurs',
#  'autonomous net zero car best next phase driverless brakes steering car',
#  'years ridden driverless car',
#  'google unveils new driverless steering car diver',
#  'ever trust driverless however children certainly',
#  'driverless may eliminate need trains',
#  'driverless car good news bad car',
#  'first question google mean driverless super love need sounds',
#  'driverless think rest crazed dislike drivers road society today',
#  'concept car driverless car ridiculous',
#  'driverless car hold breath',
#  'long deploys first driverless',
#  'driverless car sensors warn else driverless',
#  'far google evil want make driverless car',
#  'need one driverless car',
#  'thrilling future driverless car',
#  'driverless car break law',
#  'driverless car looks trust car able',
#  'driverless car love needs manual control option unpredictable circumstances',
#  'qualcomm wants make eyes driverless car',
#  'someone net driverless google car considered driver passenger need',
#  'driverless one things ignore hope goes',
#  'google amazon tinker driverless car apple stuck',
#  'economist driverless selfdriving seat design without',
#  'google got states legalize driverless mountain four years google',
#  'driverless car could enormous ecological economical benefit society',
#  'whole scene jared driverless car perfect role comin office',
#  '',
#  'interesting debate driverless car kill save two discuss',
#  'entered mental khole debate responsible driverless car kill injure',
#  'google driverless launch nova scotia',
#  'eps jared driverless erlich',
#  'pilot-less mt wrong driverless',
#  'test-driving driverless robotic car',
#  'driverless car panacea aging bring human social life',
#  'city approves rules test car public roads',
#  'driverless car may get city license',
#  'pointed blog series impact driverless',
#  'driverless car ready ca regulatory framework end',
#  'driverless car widely available - kaku',
#  'program driverless car called choose',
#  'horseless carriage car driverless car',
#  'best thing read along time driverless car mobility',
#  'dislike point driverless car',
#  'near future driverless car drive work every morning jog',
#  'defeats purpose selfselfdriving car pay attention selfdriving whats qr code',
#  'advent driverless car presents compelling software opportunity',
#  'driverless car come soon',
#  'car join um establishing driverless car test site ann associated press -',
#  'paper right-on regarding car liability',
#  'u-m center breaks ground facility test driverless',
#  'google driverless car encountered rear ended stop sign human',
#  'go read new piece driverless morality think wearing bike helmet',
#  'google got states legalize driverless car write regulations',
#  'look roadblocks facing driverless google pushing hard bring car driven computers',
#  'park fleet driverless car suburban train stations huge parking garage fancy new technology',
#  'focusing mass transit driverless car play tremendous supporting role mass',
#  'google got states legalize driverless car',
#  'wonder footage available car actually getting accident',
#  'google got states legalize driverless four years google team trying develop',
#  'google got states legalize driverless car',
#  'google plans launch driverless car next year - dailyfinance',
#  'sure would comfortable selfdriving maybe cocktail in-hand',
#  'another look driverless car via - driverless car affect design',
#  'selfdriving driverless car',
#  'driverless car could reshape cities',
#  'driverless delivery drones robots reshape',
#  'driverless car could reshape via',
#  'driverless car could reshape cities seen car dislike',
#  'real challenge driverless israeli startup mobileye raises cheaper technology via',
#  'driverless car likely end autonomous future aerial one key difference ai car',
#  'driverless car reshape',
#  'look driverless car perfect terrorist bombing',
#  'major road blocks driverless car stay hate selfdriving',
#  'driverless car could reshape cities',
#  'driverless car invented google completed miles two accident humans car hit',
#  'driverless car could reshape',
#  'bbc news - driverless car tested uk roads end',
#  'maybe dismay rest driverless',
#  'google face pressure slow rollout driverless car technology via way love',
#  'wait driverless drive fer',
#  'amount first driverless car',
#  'driverless car save postal love idea also relies innovation',
#  'driverless car could reshape cities',
#  'talk emerging industry driverless car could reshape cities',
#  'driver less car drop park pick back using cell',
#  'kean says nj could go mike',
#  'think make sense think via',
#  'must read piece driverless',
#  'driverless car invented google completed miles two accident humans car hit good',
#  'sooo excited driverless',
#  'hell would want driverless love',
#  'pumped see driverless car today going',
#  'next step driverless passengerless',
#  'driverless car reshape mark way early though researchers',
#  'one third land cities devoted parking would driverless car reshape',
#  'driverless car could reshape via ready driverless bring',
#  'driverless car seem way overhyped given infrastructure pilotless planes seem much doable',
#  'never happen driverless google',
#  'states take car car via',
#  'car drive driverless trucks may around',
#  'best motor racing series planet living driverless',
#  'driverless car could reshape',
#  'driverless car could reshape cities',
#  'raises kick driverless car technology high gear turning morning commute nap',
#  'students create smartphone-powered driverless car',
#  'rather driverless car reshape',
#  'nj getting ready driverless follow gothamist twitter love us',
#  'driverless car could reshape cities - -',
#  'driverless car could reshape via',
#  'driverless car could reshape via narrower cleaner air',
#  'projects love glass driverless car sign innovation',
#  'car driverless bob car',
#  'plug use hope last',
#  'driverless electric whoever prints one car wireless',
#  'want might get pilotless planes driverless car -',
#  'driverless car highlight need understand develop ethics morality',
#  'comes driverless car pilotless',
#  'driverless revolution rolls interesting car become',
#  'brilliant smithsonian magazine award thrun - driverless',
#  'partner make driverless car available consumers decade',
#  'environmentally friendly-but - humans',
#  'driverless car could cripple law enforcement budgets',
#  'driverless car invading skynet invading would less',
#  'driverless car could impact law enforcement budgets make limits less flexible',
#  'would love write guest blog post liability regarding selfdriving let know',
#  'city greenlights testing driverless car',
#  'driverless car really need buy car first place',
#  'believe ca start granting licenses driverless car sept',
#  'interesting gray legal pi lawyers driverless car',
#  'plan americans would ride driverless car would',
#  'want driverless listening',
#  'driverless car kill save two',
#  'driverless',
#  'driverless car',
#  'driverless feel love childhood dream owning autobot could transpire',
#  'car',
#  'tooling around selfdriving google reams written five-year-old selfdriving',
#  'driverless car kill save two',
#  'driverless car kill save two via',
#  'driverless car break via',
#  'entered driverless car passenger love whole drive',
#  'coolness driverless car accident involve human error marco della pretty',
#  'google better hurry driverless watching grandma point turn get parking spot',
#  'articles driverless car',
#  'thinking future allowed hop take ride soccer',
#  'prototype driverless',
#  'google driverless car might ugliest car ever even including behind iron',
#  'driverless car hit roadways summer',
#  'move johnny google plots driverless cabs take crowded',
#  'driverless car change everything -',
#  'google driverless go theme find ride bores tears whilst yr old child smiles ear basically',
#  'saw',
#  'drive hundreds miles bring driverless wait stop',
#  'time knew look love egg - google unveils',
#  'google invested driverless car',
#  'driverless car - brakes steering car - coming streets',
#  'take love concepts car make intentionally',
#  'driverless car supposed personal',
#  'wait driverless car take less efficient route destination pass billboards deemed',
#  ...]

# %%
freq = {}
for tweet in grouped_tweets:
  for word in tweet.split():
    if word in freq:
      freq[word] +=1
    else:
      freq[word] = 0

# %%
word_frequency = np.array(list(freq.items()))

# %%
a = sorted(freq.items(), key=lambda x: x[1], reverse=True)
a = np.array(a)

# %%
words_limit = 5
x_axis = np.array(a[:words_limit, 0])
y_axis = np.array(a[:words_limit, 1], dtype=float)

# %%
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 5 artists>

# %%
a[0:50]
# Out:
# array([['car', '5630'],
#        ['selfdriving', '3997'],
#        ['google', '2124'],
#        ['driverless', '1741'],
#        ['selfselfdriving', '1406'],
#        ['love', '557'],
#        ['autonomous', '412'],
#        ['-', '361'],
#        ['saw', '310'],
#        ['city', '288'],
#        ['get', '238'],
#        ['new', '233'],
#        ['would', '232'],
#        ['could', '228'],
#        ['one', '223'],
#        ['drive', '202'],
#        ['future', '202'],
#        ['see', '195'],
#        ['via', '195'],
#        ['need', '192'],
#        ['first', '167'],
#        ['think', '167'],
#        ['want', '164'],
#        ['technology', '159'],
#        ['make', '149'],
#        ['going', '138'],
#        ['people', '131'],
#        ['road', '126'],
#        ['steering', '123'],
#        ['way', '118'],
#        ['take', '118'],
#        ['next', '113'],
#        ['says', '108'],
#        ['dislike', '107'],
#        ['accident', '107'],
#        ['wait', '103'],
#        ['still', '99'],
#        ['really', '96'],
#        ['time', '95'],
#        ['drivers', '94'],
#        ['around', '93'],
#        ['test', '93'],
#        ['look', '93'],
#        ['go', '90'],
#        ['driver', '86'],
#        ['us', '80'],
#        ['know', '79'],
#        ['street', '78'],
#        ['much', '76'],
#        ['come', '76']], dtype='<U76')

# %%
nouns = ['car','google','traffic','accident','parking','maps','internet','fuel','city','street','insurance','future','safety','electric','human']
verbs = ['selfdriving',	'autonomous',	'love','technology','drive','steering','mastering','testing','invented','need','reshape','rides','taxis','design','excited','dislike']

# %%
# dict = [noun-verb-count]
dic = []
for noun in nouns:
  for verb in verbs:
    count = 0
    for tweet in grouped_tweets:
      for word in tweet.split():
        word = word.lower()
        if word.lower() == verb:
          if noun in tweet.split() or p.plural(noun) in tweet.split():
            count += 1
    dic.append([noun, verb, count])

# %%
nouns_verbs_freq = np.array(dic)

# %%
df3 = pd.DataFrame(nouns_verbs_freq, columns=['noun', 'verb', 'frequency']).to_csv('nouns-verbs-frequency.csv', index=None)

# %%
flights_long = pd.read_csv('nouns-verbs-frequency.csv')

# %%
flights = flights_long.pivot("noun", "verb", "frequency")

# %%
ax = sn.heatmap(flights , vmin=0, vmax=30)
